# %% [markdown]
# <a href="https://colab.research.google.com/github/ritishri/Big_Data_Assignment/blob/main/17April_Ritika_Raj_Assignment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics


x1 = [60,62,67,70,71,72,75,78]
x2 = [22,25,24,20,15,14,14,11]
y = [140,155,159,179,192,200,212,215]
sum1 = sum(x1)
sum2 = sum(x2)
sum3 = sum(y)

m1 = statistics.mean(x1)
m2 = statistics.mean(x2)
m3 = statistics.mean(y)

# print(sum1)
# print(sum2)
# print(sum3)

# print(m1)
# print(m2)
# print(m3)


a = 0
for i in x1:
  a += i*i
# print(a)

b = 0
for i in x2:
  b += i*i
# print(b)

product = 0
for i in range(len(x1)):
  product += x1[i] * y[i]
# print(product)

product2 = 0
for i in range(len(x2)):
  product2 += x2[i] * y[i]
# print(product2)

product3 = 0
for i in range(len(x2)):
  product3 += x2[i] * x1[i]
# print(product3)


x1sqr = a - (sum1 * sum1)/len(x1)
x2sqr = b - (sum2 * sum2)/len(x2)
x1y = product - (sum1 * sum3)/len(x1)
x2y = product2 - (sum2 * sum3)/len(x1)
x1x2 = product3 - (sum1 * sum2)/len(x1)

# print(x1sqr)
# print(x2sqr)
# print(x1y)
# print(x2y)
# print(x1x2)

a1 = x2sqr * x1y - x1x2 * x2y
a2 = x1sqr * x2sqr - x1x2 * x1x2
a = a1 / a2
print("b1 = ",a)

c1 = x1sqr * x2y - x1x2 * x1y
c2 = x1sqr * x2sqr - x1x2 * x1x2
c = c1 / c2
print("b2 =",c)

value = m3 - a*m1 - c*m2
print("bo = ",value)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x1, x2, y, color='r', marker='o', label='Data Points')

xx1, xx2 = np.meshgrid(range(min(x1), max(x1)), range(min(x2), max(x2)))
yy = a*xx1 + c*xx2 + value


ax.plot_surface(xx1, xx2, yy, alpha=0.5)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')
# Out:
# b1 =  3.147893102683522
# b2 = -1.6561432690175206
# bo =  -6.867487247726768
# Text(0.5, 0, 'y')

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Data
x1 = [60,62,67,70,71,72,75,78]
x2 = [22,25,24,20,15,14,14,11]
y = [140,155,159,179,192,200,212,215]

data = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})

data = sm.add_constant(data)

model = sm.OLS(data['y'], data[['const', 'x1', 'x2']]).fit()

print("b0 =", model.params['const'])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(data['x1'], data['x2'], data['y'], color='r', marker='o', label='Data Points')


xx1, xx2 = np.meshgrid(range(min(x1), max(x1)), range(min(x2), max(x2)))
yy = model.params['x1']*xx1 + model.params['x2']*xx2 + model.params['const']


ax.plot_surface(xx1, xx2, yy, alpha=0.5)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')

plt.show()
# Out:
# b0 = -6.86748724772599
