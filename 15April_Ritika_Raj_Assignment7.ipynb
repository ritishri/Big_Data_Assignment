# %% [markdown]
# <a href="https://colab.research.google.com/github/ritishri/Big_Data_Assignment/blob/main/15April_Ritika_Raj_Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = np.array([2,4,6,8]).reshape(-1, 1)
y = np.array([3,7,5,10])


model = LinearRegression()

model.fit(X, y)

y_pred = model.predict(X)

print(f'b: {model.intercept_}')
print(f'a: {model.coef_}')

plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Regression line')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# b: 1.5
# a: [0.95]
